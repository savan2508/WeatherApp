# %%
import os
import sys

def resource_path(relative_path):
    """ Get an absolute path to resource, works for dev and for PyInstaller """
    try:
        # PyInstaller creates a temp folder and stores path in _MEI PASS
        base_path = sys._MEIPASS
    except Exception:
        base_path = os.path.abspath(".")

    return os.path.join(base_path, relative_path)

# %%
import sys
import os

# Get the current directory of the test.py file
current_directory = os.getcwd()

# Add the parent directory (weatherapp) to the Python path
parent_directory = os.path.abspath(os.path.join(current_directory, '..'))
sys.path.append(parent_directory)

# %%
import pprint
from weathermap.weathermap import Weather
from dotenv import load_dotenv

# Load the contents of the .env file into the environment variables
load_dotenv()

openweather_api = os.getenv('OPENWEATHER_API')

# %%
test = Weather(apikey=openweather_api, city="tampa")

# %%
test.forcast()

# %%
test.next_12h_simplified()
# Out:
# [('2023-08-05 00:00:00', 88.86, 'clear sky'),
#  ('2023-08-05 03:00:00', 86.49, 'light rain'),
#  ('2023-08-05 06:00:00', 84.63, 'scattered clouds'),
#  ('2023-08-05 09:00:00', 81.72, 'scattered clouds')]

# %%
test.data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1691193600,
#    'main': {'temp': 89.42,
#     'feels_like': 102.02,
#     'temp_min': 85.98,
#     'temp_max': 89.42,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 72,
#     'temp_kf': 1.91},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 5.59, 'deg': 82, 'gust': 10.65},
#    'visibility': 10000,
#    'pop': 0.13,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-05 00:00:00'},
#   {'dt': 1691204400,
#    'main': {'temp': 87.49,
#     'feels_like': 99.39,
#     'temp_min': 83.64,
#     'temp_max': 87.49,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1012,
#     'humidity': 71,
#     'temp_kf': 2.14},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 7.63, 'deg': 117, 'gust': 15.55},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-05 03:00:00'},
#   {'dt': 1691215200,
#    'main': {'temp': 83.82,
#     'feels_like': 92.07,
#     'temp_min': 81.01,
#     'temp_max': 83.82,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1012,
#     'humidity': 76,
#     'temp_kf': 1.56},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 6.85, 'deg': 131, 'gust': 12.91},
#    'visibility': 10000,
#    'pop': 0.19,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-05 06:00:00'},
#   {'dt': 1691226000,
#    'main': {'temp': 79.97,
#     'feels_like': 79.97,
#     'temp_min': 79.97,
#     'temp_max': 79.97,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1011,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 4.09, 'deg': 139, 'gust': 4.52},
#    'visibility': 10000,
#    'pop': 0.05,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-05 09:00:00'},
#   {'dt': 1691236800,
#    'main': {'temp': 80.89,
#     'feels_like': 86,
#     'temp_min': 80.89,
#     'temp_max': 80.89,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1013,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 3.27, 'deg': 122, 'gust': 3.71},
#    'visibility': 10000,
#    'pop': 0.16,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-05 12:00:00'},
#   {'dt': 1691247600,
#    'main': {'temp': 89.69,
#     'feels_like': 97.86,
#     'temp_min': 89.69,
#     'temp_max': 89.69,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.46, 'deg': 336, 'gust': 2.91},
#    'visibility': 10000,
#    'pop': 0.15,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-05 15:00:00'},
#   {'dt': 1691258400,
#    'main': {'temp': 93.7,
#     'feels_like': 101.61,
#     'temp_min': 93.7,
#     'temp_max': 93.7,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1013,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 4.74, 'deg': 298, 'gust': 5.08},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.23},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-05 18:00:00'},
#   {'dt': 1691269200,
#    'main': {'temp': 91.26,
#     'feels_like': 99.18,
#     'temp_min': 91.26,
#     'temp_max': 91.26,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1012,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 4.9, 'deg': 297, 'gust': 5.91},
#    'visibility': 10000,
#    'pop': 0.29,
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-05 21:00:00'},
#   {'dt': 1691280000,
#    'main': {'temp': 88.27,
#     'feels_like': 96.69,
#     'temp_min': 88.27,
#     'temp_max': 88.27,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1012,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 55},
#    'wind': {'speed': 6.2, 'deg': 297, 'gust': 9.1},
#    'visibility': 10000,
#    'pop': 0.07,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 00:00:00'},
#   {'dt': 1691290800,
#    'main': {'temp': 84.96,
#     'feels_like': 91.87,
#     'temp_min': 84.96,
#     'temp_max': 84.96,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1013,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 3.18, 'deg': 326, 'gust': 3.76},
#    'visibility': 10000,
#    'pop': 0.13,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-06 03:00:00'},
#   {'dt': 1691301600,
#    'main': {'temp': 82.69,
#     'feels_like': 89.08,
#     'temp_min': 82.69,
#     'temp_max': 82.69,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 2.66, 'deg': 318, 'gust': 3.44},
#    'visibility': 10000,
#    'pop': 0.51,
#    'rain': {'3h': 0.7},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-06 06:00:00'},
#   {'dt': 1691312400,
#    'main': {'temp': 80.33,
#     'feels_like': 85.1,
#     'temp_min': 80.33,
#     'temp_max': 80.33,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 4.38, 'deg': 310, 'gust': 5.28},
#    'visibility': 10000,
#    'pop': 0.75,
#    'rain': {'3h': 1.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-06 09:00:00'},
#   {'dt': 1691323200,
#    'main': {'temp': 82.51,
#     'feels_like': 88.95,
#     'temp_min': 82.51,
#     'temp_max': 82.51,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1013,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 3.36, 'deg': 186, 'gust': 4.47},
#    'visibility': 10000,
#    'pop': 0.67,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 12:00:00'},
#   {'dt': 1691334000,
#    'main': {'temp': 90.03,
#     'feels_like': 98.1,
#     'temp_min': 90.03,
#     'temp_max': 90.03,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1015,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 23},
#    'wind': {'speed': 7.2, 'deg': 238, 'gust': 8.03},
#    'visibility': 10000,
#    'pop': 0.07,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 15:00:00'},
#   {'dt': 1691344800,
#    'main': {'temp': 92.17,
#     'feels_like': 101.25,
#     'temp_min': 92.17,
#     'temp_max': 92.17,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 9.33, 'deg': 238, 'gust': 7.94},
#    'visibility': 10000,
#    'pop': 0.49,
#    'rain': {'3h': 1.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 18:00:00'},
#   {'dt': 1691355600,
#    'main': {'temp': 89.46,
#     'feels_like': 98.94,
#     'temp_min': 89.46,
#     'temp_max': 89.46,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1013,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 11.99, 'deg': 255, 'gust': 12.08},
#    'visibility': 10000,
#    'pop': 0.46,
#    'rain': {'3h': 0.39},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 21:00:00'},
#   {'dt': 1691366400,
#    'main': {'temp': 86.05,
#     'feels_like': 93.92,
#     'temp_min': 86.05,
#     'temp_max': 86.05,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 8.88, 'deg': 259, 'gust': 12.8},
#    'visibility': 10000,
#    'pop': 0.44,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 00:00:00'},
#   {'dt': 1691377200,
#    'main': {'temp': 84,
#     'feels_like': 90.81,
#     'temp_min': 84,
#     'temp_max': 84,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 5.57, 'deg': 239, 'gust': 8.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-07 03:00:00'},
#   {'dt': 1691388000,
#    'main': {'temp': 83.19,
#     'feels_like': 89.64,
#     'temp_min': 83.19,
#     'temp_max': 83.19,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1014,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 71},
#    'wind': {'speed': 6.2, 'deg': 268, 'gust': 9.04},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-07 06:00:00'},
#   {'dt': 1691398800,
#    'main': {'temp': 81.97,
#     'feels_like': 87.73,
#     'temp_min': 81.97,
#     'temp_max': 81.97,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1013,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 5.37, 'deg': 222, 'gust': 6.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-07 09:00:00'},
#   {'dt': 1691409600,
#    'main': {'temp': 82.49,
#     'feels_like': 89.17,
#     'temp_min': 82.49,
#     'temp_max': 82.49,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1015,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 4.18, 'deg': 217, 'gust': 6.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 12:00:00'},
#   {'dt': 1691420400,
#    'main': {'temp': 89.38,
#     'feels_like': 97.2,
#     'temp_min': 89.38,
#     'temp_max': 89.38,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1016,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 6.31, 'deg': 243, 'gust': 7},
#    'visibility': 10000,
#    'pop': 0.08,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 15:00:00'},
#   {'dt': 1691431200,
#    'main': {'temp': 93.11,
#     'feels_like': 100.9,
#     'temp_min': 93.11,
#     'temp_max': 93.11,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1015,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 74},
#    'wind': {'speed': 8.7, 'deg': 257, 'gust': 7.81},
#    'visibility': 10000,
#    'pop': 0.07,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 18:00:00'},
#   {'dt': 1691442000,
#    'main': {'temp': 90.77,
#     'feels_like': 99.21,
#     'temp_min': 90.77,
#     'temp_max': 90.77,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 29},
#    'wind': {'speed': 10.92, 'deg': 260, 'gust': 10.76},
#    'visibility': 10000,
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 21:00:00'},
#   {'dt': 1691452800,
#    'main': {'temp': 86.47,
#     'feels_like': 94.44,
#     'temp_min': 86.47,
#     'temp_max': 86.47,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 21},
#    'wind': {'speed': 8.84, 'deg': 268, 'gust': 12.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 00:00:00'},
#   {'dt': 1691463600,
#    'main': {'temp': 84.52,
#     'feels_like': 91.98,
#     'temp_min': 84.52,
#     'temp_max': 84.52,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1014,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 6.04, 'deg': 290, 'gust': 10},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-08 03:00:00'},
#   {'dt': 1691474400,
#    'main': {'temp': 83.21,
#     'feels_like': 90.59,
#     'temp_min': 83.21,
#     'temp_max': 83.21,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 4.14, 'deg': 285, 'gust': 4.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-08 06:00:00'},
#   {'dt': 1691485200,
#    'main': {'temp': 81.88,
#     'feels_like': 88.25,
#     'temp_min': 81.88,
#     'temp_max': 81.88,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1013,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 3.62, 'deg': 189, 'gust': 3.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-08 09:00:00'},
#   {'dt': 1691496000,
#    'main': {'temp': 82.71,
#     'feels_like': 89.67,
#     'temp_min': 82.71,
#     'temp_max': 82.71,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1015,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 3.65, 'deg': 203, 'gust': 5.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 12:00:00'},
#   {'dt': 1691506800,
#    'main': {'temp': 90.03,
#     'feels_like': 97.57,
#     'temp_min': 90.03,
#     'temp_max': 90.03,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1015,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 6.71, 'deg': 244, 'gust': 7.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 15:00:00'},
#   {'dt': 1691517600,
#    'main': {'temp': 93.22,
#     'feels_like': 101.77,
#     'temp_min': 93.22,
#     'temp_max': 93.22,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 30},
#    'wind': {'speed': 9.37, 'deg': 260, 'gust': 8.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 18:00:00'},
#   {'dt': 1691528400,
#    'main': {'temp': 91.89,
#     'feels_like': 99.41,
#     'temp_min': 91.89,
#     'temp_max': 91.89,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 12.53, 'deg': 269, 'gust': 10.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 21:00:00'},
#   {'dt': 1691539200,
#    'main': {'temp': 86.59,
#     'feels_like': 93.04,
#     'temp_min': 86.59,
#     'temp_max': 86.59,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1011,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 8.28, 'deg': 247, 'gust': 11.48},
#    'visibility': 10000,
#    'pop': 0.15,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 00:00:00'},
#   {'dt': 1691550000,
#    'main': {'temp': 84.81,
#     'feels_like': 90.52,
#     'temp_min': 84.81,
#     'temp_max': 84.81,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 8.41, 'deg': 284, 'gust': 14.07},
#    'visibility': 10000,
#    'pop': 0.17,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-09 03:00:00'},
#   {'dt': 1691560800,
#    'main': {'temp': 83.26,
#     'feels_like': 88.65,
#     'temp_min': 83.26,
#     'temp_max': 83.26,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1013,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 4.03, 'deg': 285, 'gust': 4.65},
#    'visibility': 10000,
#    'pop': 0.16,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-09 06:00:00'},
#   {'dt': 1691571600,
#    'main': {'temp': 81.77,
#     'feels_like': 86.86,
#     'temp_min': 81.77,
#     'temp_max': 81.77,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1012,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 2.64, 'deg': 355, 'gust': 3.18},
#    'visibility': 10000,
#    'pop': 0.22,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-09 09:00:00'},
#   {'dt': 1691582400,
#    'main': {'temp': 81.75,
#     'feels_like': 87.26,
#     'temp_min': 81.75,
#     'temp_max': 81.75,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1013,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 5.19, 'deg': 158, 'gust': 6.96},
#    'visibility': 10000,
#    'pop': 0.12,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 12:00:00'},
#   {'dt': 1691593200,
#    'main': {'temp': 89.87,
#     'feels_like': 96.22,
#     'temp_min': 89.87,
#     'temp_max': 89.87,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1013,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 6.22, 'deg': 218, 'gust': 7.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 15:00:00'},
#   {'dt': 1691604000,
#    'main': {'temp': 93.61,
#     'feels_like': 101.41,
#     'temp_min': 93.61,
#     'temp_max': 93.61,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1012,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 9.13, 'deg': 268, 'gust': 8.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 18:00:00'},
#   {'dt': 1691614800,
#    'main': {'temp': 92.53,
#     'feels_like': 100.85,
#     'temp_min': 92.53,
#     'temp_max': 92.53,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1012,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 11.7, 'deg': 273, 'gust': 9.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 21:00:00'}],
#  'city': {'id': 0,
#   'name': 'Riverview',
#   'coord': {'lat': 27.845, 'lon': -82.3125},
#   'country': 'US',
#   'population': 0,
#   'timezone': -14400,
#   'sunrise': 1691146413,
#   'sunset': 1691194627}}
