# %%
import os
import sys

def resource_path(relative_path):
    """ Get an absolute path to resource, works for dev and for PyInstaller """
    try:
        # PyInstaller creates a temp folder and stores path in _MEI PASS
        base_path = sys._MEIPASS
    except Exception:
        base_path = os.path.abspath(".")

    return os.path.join(base_path, relative_path)

# %%
import sys
import os

# Get the current directory of the test.py file
current_directory = os.getcwd()

# Add the parent directory (weatherapp) to the Python path
parent_directory = os.path.abspath(os.path.join(current_directory, '..'))
sys.path.append(parent_directory)

# %%
import pprint
from weathermap.weathermap import Weather
from dotenv import load_dotenv

# Load the contents of the .env file into the environment variables
load_dotenv()

openweather_api = os.getenv('OPENWEATHER_API')
access_token = os.getenv('IPINFO_TOKEN')

# %%
test = Weather(apikey="openweather_api", city="tampa", track_location=False)

# %%
test.forcast()

# %%
test.data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1691301600,
#    'main': {'temp': 81.46,
#     'feels_like': 89.11,
#     'temp_min': 81.46,
#     'temp_max': 85.51,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 87,
#     'temp_kf': -2.25},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 4.85, 'deg': 316, 'gust': 6.13},
#    'visibility': 10000,
#    'pop': 0.14,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-06 06:00:00'},
#   {'dt': 1691312400,
#    'main': {'temp': 82.54,
#     'feels_like': 90.14,
#     'temp_min': 82.54,
#     'temp_max': 84.69,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1014,
#     'humidity': 80,
#     'temp_kf': -1.19},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
# ...

# %%
test.city

# %%
test.state

# %%
test.country

# %%
import re
timeout = "5 Month"
match = re.match(r'^\d+\s*[a-zA-Z]+$', timeout)
if match:
    print("Pass")
# Out:
# Pass

# %%
def timeout_time_clean(timeout):
    match = re.match(r'^\d+\s*[a-zA-Z]+$', timeout)
    if match:
        match = re.search(r'\d+', timeout)
        if match:
            # Extract the number part
            number = match.group()
            # Extract the character part (if any)
            characters = timeout[match.end():].strip()
            if characters[0].upper() == 'S':
                time_unit = "seconds"
            elif characters[0].upper() == 'M':
                time_unit = "minutes"
            elif characters[0].upper() == 'H':
                time_unit = "hours"
            elif characters[0].upper() == 'D':
                time_unit = "days"
            else:
                raise ValueError("Please provide a valid timeout interval")
            
            return f"{time_unit}={number}"
        else:
            raise ValueError("Please provide valid time interval")

    else:
        raise ValueError("Please provide a valid timeout interval")

# %%
timeout = "1 sec"
print(timeout_time_clean(timeout=timeout))
# Out:
# seconds=1

# %%
def func(**kwargs):
    return kwargs
    
a = func(city="Tampa", state="Florida", zip=33569)

# %%
a
# Out:
# {'city': 'Tampa', 'state': 'Florida', 'zip': 33569}

# %%
type(a)
# Out:
# dict

# %%
a.keys()
# Out:
# dict_keys(['city', 'state', 'zip'])

# %%
def validate_name(input_dict: dict):
    dicty = {
        "city": "",
        "state": "",
        "country": "",
        "zip_code": "",
        "lat": "",
        "lon": "",
        "req_type": "",
        "date_time": ""
    }
    for key in input_dict.keys():
        if key in dicty.keys() and (input_dict[key] is not None):
            dicty[key] = input_dict[key]

    for key, value in dicty.items():
        locals()[key] = value
    
    return dicty

# %%
validate_name(a)
# Out:
# {'city': 'Tampa',
#  'state': 'Florida',
#  'country': '',
#  'zip_code': '',
#  'lat': '',
#  'lon': '',
#  'req_type': '',
#  'date_time': ''}

# %%
a
# Out:
# {'city': 'Tampa', 'state': 'Florida', 'zip': 33569}

# %%
a['city'][0:2]
# Out:
# 'Ta'

# %%
from weathermap.WeatherCache import WeatherCache
WeatherCache()

# %%
WeatherCache().create_cache(city="Tampa", data=a)

# %%
WeatherCache().get_cached_weather(city="Tampa", timeout="hours=1", req_type="weather")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\sawan\OneDrive\Programming\Projects\WeatherApp\weathermap\WeatherCache.py:86, in WeatherCache.get_cached_weather(self, city, req_type, timeout)
#      85     # No cached file found for the same city within the past 1 hour
# ---> 86     raise FileNotFoundError(f"File not found: {city}")
#      88 except OSError:
#
# FileNotFoundError: File not found: Tampa
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 WeatherCache().get_cached_weather(city="Tampa", timeout="hours=1", req_type="weather")
#
# File c:\Users\sawan\OneDrive\Programming\Projects\WeatherApp\weathermap\WeatherCache.py:89, in WeatherCache.get_cached_weather(self, city, req_type, timeout)
# ...

# %%
os.path.getsize(WeatherCache().cache_directory)
# Out:
# 4096

# %%
os.path.getsize('test.py')
# Out:
# 525
