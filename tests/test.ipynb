# %%
import os
import sys

def resource_path(relative_path):
    """ Get an absolute path to resource, works for dev and for PyInstaller """
    try:
        # PyInstaller creates a temp folder and stores path in _MEI PASS
        base_path = sys._MEIPASS
    except Exception:
        base_path = os.path.abspath(".")

    return os.path.join(base_path, relative_path)

# %%
import sys
import os

# Get the current directory of the test.py file
current_directory = os.getcwd()

# Add the parent directory (weatherapp) to the Python path
parent_directory = os.path.abspath(os.path.join(current_directory, '..'))
sys.path.append(parent_directory)

# %%
import pprint
from weathermap.weathermap import Weather
from dotenv import load_dotenv

# Load the contents of the .env file into the environment variables
load_dotenv()

openweather_api = os.getenv('OPENWEATHER_API')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pprint
# ----> 2 from weathermap.weathermap import Weather
#       3 from dotenv import load_dotenv
#       5 # Load the contents of the .env file into the environment variables
#
# File c:\Users\sawan\OneDrive\Programming\Projects\WeatherApp\weathermap\__init__.py:1
# ----> 1 from weathermap.weathermap import Weather
#       3 __all__ = ['Weather']
#
# File c:\Users\sawan\OneDrive\Programming\Projects\WeatherApp\weathermap\weathermap.py:2
#       1 import requests
# ----> 2 from WeatherCache import WeatherCache
#       5 class Weather(WeatherCache):
#       6     """
#       7     Weather Class:
#       8
#    (...)
#      31         >>> weather1.next12h_simplified()
#      32     """
#
# ModuleNotFoundError: No module named 'WeatherCache'

# %%
test = Weather(apikey="openweather_api", city="tampa")

# %%
test.forcast()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 test.forcast()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\weathermap\weathermap.py:104, in Weather.forcast(self)
#     101         self.data = r.json()
#     103         if self.data["cod"] != "200":
# --> 104             raise ValueError(self.data["message"], "Check spelling or provide state and country code, "
#     105                                                    "or try zipcode and country.")
#     107 elif self.lat and self.lon:
#     109     url = f"{self.base_url}lat={self.lat}&lon={self.lon}&APPID={self.apikey}&units={self.units}"
#
# ValueError: ('Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.', 'Check spelling or provide state and country code, or try zipcode and country.')

# %%
test.next_12h_simplified()
# Out:
# [('2023-08-06 06:00:00', 81.46, 'broken clouds'),
#  ('2023-08-06 09:00:00', 82.54, 'broken clouds'),
#  ('2023-08-06 12:00:00', 83.97, 'light rain'),
#  ('2023-08-06 15:00:00', 90.88, 'clear sky')]

# %%
test.data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1691301600,
#    'main': {'temp': 81.46,
#     'feels_like': 89.11,
#     'temp_min': 81.46,
#     'temp_max': 85.51,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 87,
#     'temp_kf': -2.25},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 4.85, 'deg': 316, 'gust': 6.13},
#    'visibility': 10000,
#    'pop': 0.14,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-06 06:00:00'},
#   {'dt': 1691312400,
#    'main': {'temp': 82.54,
#     'feels_like': 90.14,
#     'temp_min': 82.54,
#     'temp_max': 84.69,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1014,
#     'humidity': 80,
#     'temp_kf': -1.19},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 1.72, 'deg': 293, 'gust': 3.18},
#    'visibility': 10000,
#    'pop': 0.24,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-06 09:00:00'},
#   {'dt': 1691323200,
#    'main': {'temp': 83.97,
#     'feels_like': 91.72,
#     'temp_min': 83.97,
#     'temp_max': 85.21,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1015,
#     'humidity': 74,
#     'temp_kf': -0.69},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 1.54, 'deg': 278, 'gust': 3.44},
#    'visibility': 10000,
#    'pop': 0.25,
#    'rain': {'3h': 0.23},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 12:00:00'},
#   {'dt': 1691334000,
#    'main': {'temp': 90.88,
#     'feels_like': 98.35,
#     'temp_min': 90.88,
#     'temp_max': 90.88,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1016,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 6.13, 'deg': 224, 'gust': 6.42},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 15:00:00'},
#   {'dt': 1691344800,
#    'main': {'temp': 93.22,
#     'feels_like': 101.77,
#     'temp_min': 93.22,
#     'temp_max': 93.22,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 24},
#    'wind': {'speed': 12.66, 'deg': 247, 'gust': 10.89},
#    'visibility': 10000,
#    'pop': 0.46,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 18:00:00'},
#   {'dt': 1691355600,
#    'main': {'temp': 93.09,
#     'feels_like': 100.27,
#     'temp_min': 93.09,
#     'temp_max': 93.09,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 55},
#    'wind': {'speed': 12.15, 'deg': 268, 'gust': 10.54},
#    'visibility': 10000,
#    'pop': 0.13,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-06 21:00:00'},
#   {'dt': 1691366400,
#    'main': {'temp': 89.44,
#     'feels_like': 96.8,
#     'temp_min': 89.44,
#     'temp_max': 89.44,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 32},
#    'wind': {'speed': 8.25, 'deg': 262, 'gust': 9.04},
#    'visibility': 10000,
#    'pop': 0.07,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 00:00:00'},
#   {'dt': 1691377200,
#    'main': {'temp': 87.35,
#     'feels_like': 95.09,
#     'temp_min': 87.35,
#     'temp_max': 87.35,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1016,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 30},
#    'wind': {'speed': 7.85, 'deg': 267, 'gust': 9.66},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-07 03:00:00'},
#   {'dt': 1691388000,
#    'main': {'temp': 86.16,
#     'feels_like': 93.74,
#     'temp_min': 86.16,
#     'temp_max': 86.16,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 17},
#    'wind': {'speed': 5.95, 'deg': 279, 'gust': 7.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-07 06:00:00'},
#   {'dt': 1691398800,
#    'main': {'temp': 84.65,
#     'feels_like': 91.54,
#     'temp_min': 84.65,
#     'temp_max': 84.65,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1015,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 3.11, 'deg': 288, 'gust': 4.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-07 09:00:00'},
#   {'dt': 1691409600,
#    'main': {'temp': 85.39,
#     'feels_like': 93.2,
#     'temp_min': 85.39,
#     'temp_max': 85.39,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1017,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 3.94, 'deg': 213, 'gust': 5.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 12:00:00'},
#   {'dt': 1691420400,
#    'main': {'temp': 90.79,
#     'feels_like': 99.82,
#     'temp_min': 90.79,
#     'temp_max': 90.79,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1018,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 7.38, 'deg': 226, 'gust': 7.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 15:00:00'},
#   {'dt': 1691431200,
#    'main': {'temp': 93.07,
#     'feels_like': 102.06,
#     'temp_min': 93.07,
#     'temp_max': 93.07,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1017,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 11.52, 'deg': 237, 'gust': 8.79},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 18:00:00'},
#   {'dt': 1691442000,
#    'main': {'temp': 92.48,
#     'feels_like': 101.95,
#     'temp_min': 92.48,
#     'temp_max': 92.48,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 11.12, 'deg': 261, 'gust': 8.28},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.1},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-07 21:00:00'},
#   {'dt': 1691452800,
#    'main': {'temp': 89.11,
#     'feels_like': 97.61,
#     'temp_min': 89.11,
#     'temp_max': 89.11,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 29},
#    'wind': {'speed': 10.2, 'deg': 266, 'gust': 10.65},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 00:00:00'},
#   {'dt': 1691463600,
#    'main': {'temp': 86.68,
#     'feels_like': 94.93,
#     'temp_min': 86.68,
#     'temp_max': 86.68,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1017,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 7.58, 'deg': 280, 'gust': 9.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-08 03:00:00'},
#   {'dt': 1691474400,
#    'main': {'temp': 85.37,
#     'feels_like': 93.56,
#     'temp_min': 85.37,
#     'temp_max': 85.37,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 5.79, 'deg': 296, 'gust': 7.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-08 06:00:00'},
#   {'dt': 1691485200,
#    'main': {'temp': 84.18,
#     'feels_like': 91.54,
#     'temp_min': 84.18,
#     'temp_max': 84.18,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1015,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 0.22, 'deg': 342, 'gust': 1.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-08 09:00:00'},
#   {'dt': 1691496000,
#    'main': {'temp': 84.58,
#     'feels_like': 92.46,
#     'temp_min': 84.58,
#     'temp_max': 84.58,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1017,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 5.57, 'deg': 163, 'gust': 7.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 12:00:00'},
#   {'dt': 1691506800,
#    'main': {'temp': 90.27,
#     'feels_like': 98.62,
#     'temp_min': 90.27,
#     'temp_max': 90.27,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1018,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 6.73, 'deg': 213, 'gust': 6.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 15:00:00'},
#   {'dt': 1691517600,
#    'main': {'temp': 93.45,
#     'feels_like': 103.59,
#     'temp_min': 93.45,
#     'temp_max': 93.45,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1016,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 10.63, 'deg': 240, 'gust': 8.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 18:00:00'},
#   {'dt': 1691528400,
#    'main': {'temp': 93.45,
#     'feels_like': 103.59,
#     'temp_min': 93.45,
#     'temp_max': 93.45,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 13.31, 'deg': 269, 'gust': 9.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-08 21:00:00'},
#   {'dt': 1691539200,
#    'main': {'temp': 88.5,
#     'feels_like': 97.23,
#     'temp_min': 88.5,
#     'temp_max': 88.5,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1014,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 22},
#    'wind': {'speed': 9.8, 'deg': 275, 'gust': 10.76},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 00:00:00'},
#   {'dt': 1691550000,
#    'main': {'temp': 86.41,
#     'feels_like': 94.75,
#     'temp_min': 86.41,
#     'temp_max': 86.41,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1016,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 9.26, 'deg': 315, 'gust': 12.01},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-09 03:00:00'},
#   {'dt': 1691560800,
#    'main': {'temp': 85.08,
#     'feels_like': 92.14,
#     'temp_min': 85.08,
#     'temp_max': 85.08,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 17},
#    'wind': {'speed': 3.58, 'deg': 328, 'gust': 4.25},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-09 06:00:00'},
#   {'dt': 1691571600,
#    'main': {'temp': 82.99,
#     'feels_like': 89.49,
#     'temp_min': 82.99,
#     'temp_max': 82.99,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 21},
#    'wind': {'speed': 4.27, 'deg': 44, 'gust': 4.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-09 09:00:00'},
#   {'dt': 1691582400,
#    'main': {'temp': 83.55,
#     'feels_like': 90.75,
#     'temp_min': 83.55,
#     'temp_max': 83.55,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1015,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 4.25, 'deg': 140, 'gust': 5.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 12:00:00'},
#   {'dt': 1691593200,
#    'main': {'temp': 89.71,
#     'feels_like': 98.44,
#     'temp_min': 89.71,
#     'temp_max': 89.71,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 5.66, 'deg': 203, 'gust': 5.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 15:00:00'},
#   {'dt': 1691604000,
#    'main': {'temp': 93.88,
#     'feels_like': 103.28,
#     'temp_min': 93.88,
#     'temp_max': 93.88,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 7.85, 'deg': 239, 'gust': 5.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 18:00:00'},
#   {'dt': 1691614800,
#    'main': {'temp': 94.39,
#     'feels_like': 104.47,
#     'temp_min': 94.39,
#     'temp_max': 94.39,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1013,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 12.44, 'deg': 272, 'gust': 8.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-09 21:00:00'},
#   {'dt': 1691625600,
#    'main': {'temp': 89.24,
#     'feels_like': 98.98,
#     'temp_min': 89.24,
#     'temp_max': 89.24,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1013,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 10.07, 'deg': 300, 'gust': 10.51},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-10 00:00:00'},
#   {'dt': 1691636400,
#    'main': {'temp': 86.38,
#     'feels_like': 95.11,
#     'temp_min': 86.38,
#     'temp_max': 86.38,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.71, 'deg': 314, 'gust': 3.94},
#    'visibility': 10000,
#    'pop': 0.41,
#    'rain': {'3h': 0.23},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-10 03:00:00'},
#   {'dt': 1691647200,
#    'main': {'temp': 85.3,
#     'feels_like': 93.4,
#     'temp_min': 85.3,
#     'temp_max': 85.3,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 1.77, 'deg': 249, 'gust': 3.24},
#    'visibility': 10000,
#    'pop': 0.44,
#    'rain': {'3h': 0.47},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-10 06:00:00'},
#   {'dt': 1691658000,
#    'main': {'temp': 83.84,
#     'feels_like': 91.44,
#     'temp_min': 83.84,
#     'temp_max': 83.84,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1014,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 3.36, 'deg': 138, 'gust': 3.85},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-10 09:00:00'},
#   {'dt': 1691668800,
#    'main': {'temp': 83.84,
#     'feels_like': 92.12,
#     'temp_min': 83.84,
#     'temp_max': 83.84,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 30},
#    'wind': {'speed': 7.09, 'deg': 158, 'gust': 9.08},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-10 12:00:00'},
#   {'dt': 1691679600,
#    'main': {'temp': 89.56,
#     'feels_like': 97.07,
#     'temp_min': 89.56,
#     'temp_max': 89.56,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 8.34, 'deg': 181, 'gust': 9.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-10 15:00:00'},
#   {'dt': 1691690400,
#    'main': {'temp': 94.03,
#     'feels_like': 102.96,
#     'temp_min': 94.03,
#     'temp_max': 94.03,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 8.81, 'deg': 230, 'gust': 8.63},
#    'visibility': 10000,
#    'pop': 0.1,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-10 18:00:00'},
#   {'dt': 1691701200,
#    'main': {'temp': 92.98,
#     'feels_like': 103.14,
#     'temp_min': 92.98,
#     'temp_max': 92.98,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1014,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 19},
#    'wind': {'speed': 12.24, 'deg': 229, 'gust': 10.69},
#    'visibility': 10000,
#    'pop': 0.28,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-10 21:00:00'},
#   {'dt': 1691712000,
#    'main': {'temp': 89.62,
#     'feels_like': 99.32,
#     'temp_min': 89.62,
#     'temp_max': 89.62,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1014,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 39},
#    'wind': {'speed': 7.58, 'deg': 238, 'gust': 7.87},
#    'visibility': 10000,
#    'pop': 0.44,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-08-11 00:00:00'},
#   {'dt': 1691722800,
#    'main': {'temp': 88,
#     'feels_like': 97.05,
#     'temp_min': 88,
#     'temp_max': 88,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1015,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.2, 'deg': 237, 'gust': 4.23},
#    'visibility': 10000,
#    'pop': 0.58,
#    'rain': {'3h': 0.19},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-08-11 03:00:00'}],
#  'city': {'id': 4174757,
#   'name': 'Tampa',
#   'coord': {'lat': 27.9475, 'lon': -82.4584},
#   'country': 'US',
#   'population': 335709,
#   'timezone': -14400,
#   'sunrise': 1691319305,
#   'sunset': 1691367385}}
